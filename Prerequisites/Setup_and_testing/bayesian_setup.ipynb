# %% [markdown]
# ### Check package installations

# %%
import baybe

import os
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# If you receive a "ModuleNotFoundError" error message, create a new code cell and try executing the next line in this new cell (copy and paste the following command directly):
# > !pip install module
#
# where module is the name of the module not found (make sure to REPLACE the "module" word with the name of the module you want to install!). Then, run again again the import code cell above.
#
# If the problem persists, please contact the organizers.
